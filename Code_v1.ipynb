# %%
import pandas as pd

# %%
covidData = pd.read_csv("data/covid_19_data.csv")

# %%
covidData.head()
# Out:
#    SNo ObservationDate Province/State  Country/Region      Last Update  \
# 0    1      01/22/2020          Anhui  Mainland China  1/22/2020 17:00
# 1    2      01/22/2020        Beijing  Mainland China  1/22/2020 17:00
# 2    3      01/22/2020      Chongqing  Mainland China  1/22/2020 17:00
# 3    4      01/22/2020         Fujian  Mainland China  1/22/2020 17:00
# 4    5      01/22/2020          Gansu  Mainland China  1/22/2020 17:00
#
#    Confirmed  Deaths  Recovered
# 0        1.0     0.0        0.0
# 1       14.0     0.0        0.0
# 2        6.0     0.0        0.0
# 3        1.0     0.0        0.0
# 4        0.0     0.0        0.0

# %%
covidData.shape
# Out:
# (13209, 8)

# %% [markdown]
# There are total of 13209 observations with 8 columns

# %%
covidMeasures = pd.read_csv("data/COVID 19 Containment measures data.csv")

# %%
covidMeasures.head()
# Out:
#     ID Applies To         Country    Date Start Date end intended  \
# 0  163        NaN         Austria  Mar 16, 2020               NaN
# 1  132        NaN         Germany  Feb 01, 2020               NaN
# 2  578        NaN  United Kingdom  Mar 20, 2020               NaN
# 3  372        NaN  United Kingdom  Mar 16, 2020               NaN
# 4  357        NaN  United Kingdom  Mar 16, 2020               NaN
#
#                   Description of measure implemented Exceptions  \
# 0  On 10 March 2020 government announced that all...        NaN
# 1  102 German citizens and 26 relatives, all of w...        NaN
# 2        All schools, nurseries and colleges closed.        NaN
# 3  If one person in any household has a persisten...        NaN
# 4  By the weekend, those with the most serious he...        NaN
#
#   Implementing City Implementing State/Province  \
# 0               NaN                         NaN
# 1               NaN                         NaN
# ...

# %%
covidMeasures.shape
# Out:
# (1703, 16)

# %%
wdiData = pd.read_csv("data/WDIndicators.csv")

# %%
wdiData.head()
# Out:
#   Country Name Country Code  \
# 0        Aruba          ABW
# 1        Aruba          ABW
# 2        Aruba          ABW
# 3        Aruba          ABW
# 4        Aruba          ABW
#
#                                       Indicator Name  Indicator Code  1960  \
# 0  Specialist surgical workforce (per 100,000 pop...  SH.MED.SAOP.P5   NaN
# 1                      Physicians (per 1,000 people)  SH.MED.PHYS.ZS   NaN
# 2             Nurses and midwives (per 1,000 people)  SH.MED.NUMW.P3   NaN
# 3        Community health workers (per 1,000 people)  SH.MED.CMHW.P3   NaN
# 4                   Hospital beds (per 1,000 people)  SH.MED.BEDS.ZS   NaN
#
#    1961  1962  1963  1964  1965  ...  2010  2011  2012  2013  2014  2015  \
# 0   NaN   NaN   NaN   NaN   NaN  ...   NaN   NaN   NaN   NaN   NaN   NaN
# 1   NaN   NaN   NaN   NaN   NaN  ...   NaN   NaN   NaN   NaN   NaN   NaN
# 2   NaN   NaN   NaN   NaN   NaN  ...   NaN   NaN   NaN   NaN   NaN   NaN
# ...

# %%
wdiData.shape
# Out:
# (66000, 64)

# %% [markdown]
# Data Description:
# * "covidData" - Dataset about number of Covid-19 cases worldwide
# * "covidMeasures" - Measures taken by each country to combat Covid-19
# * "wdiData" - World Development Indicators displaying the various indicators of each country from 1960 to 2018
